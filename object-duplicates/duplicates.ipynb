# %% [markdown]
# ## Detect Duplicate Objects
#
# This notebook authenticates to Evo, lets you choose an instance, and then lets you pick one or more workspaces to scan.
#
# Fill in your Evo app credentials, run the login cell, choose your instance, tick the workspaces you want, then click the Analyze button in the widget.

# %%
import importlib

from IPython.display import display

import duplicate_analysis
import instance_workspace_selector

importlib.reload(duplicate_analysis)
importlib.reload(instance_workspace_selector)
InstanceWorkspaceSelectorWidget = instance_workspace_selector.InstanceWorkspaceSelectorWidget

# Evo app credentials
client_id = "daves-evo-client"

manager = await InstanceWorkspaceSelectorWidget.with_auth_code(client_id=client_id).login()
display(manager)
